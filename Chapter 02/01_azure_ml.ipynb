# %%
from azureml.core import Workspace, Experiment

# Configure experiment
ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='cifar10_cnn_experiment')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# Note, we have launched a browser for you to login. For old experience with device code, use "az login --use-device-code"
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute

# Create the cluster
config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', max_nodes=4)
cluster = ComputeTarget.create(ws, 'cluster', config)
cluster.wait_for_completion(show_output=True)
# Out:
# Creating......
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.train.estimator import Estimator

# Submit the training script to the cluster
estimator = Estimator(compute_target=cluster, source_directory='./code', entry_script='train.py', pip_packages=['keras==2.3.0', 'tensorflow==1.13.2'])
run = exp.submit(estimator)
run.wait_for_completion(show_output=True)
# Out:
# Preparing
# 5ba1f0778181: Preparing
# 658e73e9fcdf: Preparing
# b48835f37b9c: Preparing
# a7c59d42f9e5: Preparing
# bb7a0d4412a3: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# f972d99ebaf9: Waiting
# 658e73e9fcdf: Waiting
# 9fb03c149bb0: Waiting
# 55d9efd86373: Waiting
# b48835f37b9c: Waiting
# 1511f3064e1e: Waiting
# a7c59d42f9e5: Waiting
# fe09032048fd: Waiting
# cbe733e9771d: Waiting
# 74218ef6464a: Waiting
# bb7a0d4412a3: Waiting
# 5ba1f0778181: Waiting
# 5f08512fd434: Waiting
# 50858308da3d: Waiting
# c7bb31fc0e08: Waiting
# cfcf53a0b60f: Layer already exists
# 5e0476c9c267: Layer already exists
# 1a770bc0c7a5: Layer already exists
# 7c61a36bb5ac: Layer already exists
# 39c506a41c09: Layer already exists
# 55d9efd86373: Layer already exists
# 9fb03c149bb0: Layer already exists
# f972d99ebaf9: Layer already exists
# fe09032048fd: Layer already exists
# 1511f3064e1e: Layer already exists
# 74218ef6464a: Layer already exists
# 5ba1f0778181: Layer already exists
# cbe733e9771d: Layer already exists
# 658e73e9fcdf: Layer already exists
# b48835f37b9c: Layer already exists
# bb7a0d4412a3: Layer already exists
# a7c59d42f9e5: Layer already exists
# c7bb31fc0e08: Layer already exists
# 50858308da3d: Layer already exists
# 5f08512fd434: Layer already exists
# latest: digest: sha256:1327b689904aa684f82564fcd4190758af6e95108f02dd61bc0753820195a515 size: 4514
# 2021/07/15 01:40:41 Successfully pushed image: 9a91d04a40a748aa93c8c7bc9a8042da.azurecr.io/azureml/azureml_1139d3837208abba977b53ee2983b256:latest
# 2021/07/15 01:40:41 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 226.440369)
# 2021/07/15 01:40:41 Populating digests for step ID: acb_step_0...
# 2021/07/15 01:40:43 Successfully populated digests for step ID: acb_step_0
# 2021/07/15 01:40:43 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 110.993426)
# 2021/07/15 01:40:43 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.579054)
# 2021/07/15 01:40:43 The following dependencies were found:
# 2021/07/15 01:40:43
# - image:
#     registry: 9a91d04a40a748aa93c8c7bc9a8042da.azurecr.io
#     repository: azureml/azureml_1139d3837208abba977b53ee2983b256
#     tag: latest
#     digest: sha256:1327b689904aa684f82564fcd4190758af6e95108f02dd61bc0753820195a515
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
# - image:
#     registry: 9a91d04a40a748aa93c8c7bc9a8042da.azurecr.io
#     repository: azureml/azureml_1139d3837208abba977b53ee2983b256
#     tag: "1"
#     digest: sha256:1327b689904aa684f82564fcd4190758af6e95108f02dd61bc0753820195a515
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
#
# Run ID: ca1 was successful after 5m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_30342395f133dce1ab6228c8e04e85cebef5284b37e130f8635d4ad23e26329f_d.txt
# ========================================================================================================================
#
# 2021-07-15T01:45:29Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/melbourne-ai/azureml/cifar10_cnn_experiment_1626312878_de90fada/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/melbourne-ai/azureml/cifar10_cnn_experiment_1626312878_de90fada/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=92221 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/melbourne-ai/azureml/cifar10_cnn_experiment_1626312878_de90fada/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-07-15T01:45:29Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/melbourne-ai/azureml/cifar10_cnn_experiment_1626312878_de90fada/mounts/workspaceblobstore
# 2021-07-15T01:45:29Z The vmsize standard_d2_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-07-15T01:45:29Z Starting output-watcher...
# 2021-07-15T01:45:29Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-07-15T01:45:29Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-07-15T01:45:29Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1139d3837208abba977b53ee2983b256
# 4bbfd2c87b75: Pulling fs layer
# d2e110be24e1: Pulling fs layer
# 889a7173dcfe: Pulling fs layer
# 7a7a145ebf57: Pulling fs layer
# 1ae81884420d: Pulling fs layer
# fcdf07e25452: Pulling fs layer
# 95262654cd7f: Pulling fs layer
# 520cb0fab4f5: Pulling fs layer
# 00c1c086d027: Pulling fs layer
# 282c4a3b6fb6: Pulling fs layer
# f4201c7ca826: Pulling fs layer
# 5d2ecd2e22cc: Pulling fs layer
# 5909ce06cb70: Pulling fs layer
# d2e2a8fd419a: Pulling fs layer
# aec3308b762e: Pulling fs layer
# 4c10cde1ba70: Pulling fs layer
# 337ed2d83ff7: Pulling fs layer
# 3a87d3a87fe0: Pulling fs layer
# 3ab0930dc790: Pulling fs layer
# d97a0f69668e: Pulling fs layer
# 7a7a145ebf57: Waiting
# 1ae81884420d: Waiting
# fcdf07e25452: Waiting
# 95262654cd7f: Waiting
# 520cb0fab4f5: Waiting
# 00c1c086d027: Waiting
# 282c4a3b6fb6: Waiting
# f4201c7ca826: Waiting
# 5d2ecd2e22cc: Waiting
# 5909ce06cb70: Waiting
# d2e2a8fd419a: Waiting
# aec3308b762e: Waiting
# 4c10cde1ba70: Waiting
# 337ed2d83ff7: Waiting
# 3a87d3a87fe0: Waiting
# 3ab0930dc790: Waiting
# d97a0f69668e: Waiting
# d2e110be24e1: Verifying Checksum
# d2e110be24e1: Download complete
# 889a7173dcfe: Verifying Checksum
# 889a7173dcfe: Download complete
# 4bbfd2c87b75: Verifying Checksum
# 4bbfd2c87b75: Download complete
# fcdf07e25452: Verifying Checksum
# fcdf07e25452: Download complete
# 1ae81884420d: Verifying Checksum
# 1ae81884420d: Download complete
# 520cb0fab4f5: Verifying Checksum
# 520cb0fab4f5: Download complete
# 7a7a145ebf57: Verifying Checksum
# 7a7a145ebf57: Download complete
# 282c4a3b6fb6: Verifying Checksum
# 282c4a3b6fb6: Download complete
# 00c1c086d027: Verifying Checksum
# 00c1c086d027: Download complete
# f4201c7ca826: Verifying Checksum
# f4201c7ca826: Download complete
# 5d2ecd2e22cc: Verifying Checksum
# 5d2ecd2e22cc: Download complete
# 5909ce06cb70: Verifying Checksum
# 5909ce06cb70: Download complete
# d2e2a8fd419a: Verifying Checksum
# d2e2a8fd419a: Download complete
# aec3308b762e: Verifying Checksum
# aec3308b762e: Download complete
# 95262654cd7f: Verifying Checksum
# 95262654cd7f: Download complete
# 337ed2d83ff7: Verifying Checksum
# 337ed2d83ff7: Download complete
# 3a87d3a87fe0: Verifying Checksum
# 3a87d3a87fe0: Download complete
# 3ab0930dc790: Verifying Checksum
# d97a0f69668e: Verifying Checksum
# d97a0f69668e: Download complete
# 3ab0930dc790: Download complete
# 4c10cde1ba70: Verifying Checksum
# 4c10cde1ba70: Download complete
# 4bbfd2c87b75: Pull complete
# d2e110be24e1: Pull complete
# 889a7173dcfe: Pull complete
# 7a7a145ebf57: Pull complete
# 1ae81884420d: Pull complete
# fcdf07e25452: Pull complete
# 95262654cd7f: Pull complete
# 520cb0fab4f5: Pull complete
# 00c1c086d027: Pull complete
# 282c4a3b6fb6: Pull complete
# f4201c7ca826: Pull complete
# 5d2ecd2e22cc: Pull complete
# 5909ce06cb70: Pull complete
# d2e2a8fd419a: Pull complete
# aec3308b762e: Pull complete
# 4c10cde1ba70: Pull complete
# 337ed2d83ff7: Pull complete
# 3a87d3a87fe0: Pull complete
# 3ab0930dc790: Pull complete
# d97a0f69668e: Pull complete
# Digest: sha256:1327b689904aa684f82564fcd4190758af6e95108f02dd61bc0753820195a515
# Status: Downloaded newer image for 9a91d04a40a748aa93c8c7bc9a8042da.azurecr.io/azureml/azureml_1139d3837208abba977b53ee2983b256:latest
# 9a91d04a40a748aa93c8c7bc9a8042da.azurecr.io/azureml/azureml_1139d3837208abba977b53ee2983b256:latest
# 2021-07-15T01:47:24Z The vmsize standard_d2_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-07-15T01:47:25Z Check if container cifar10_cnn_experiment_1626312878_de90fada already exist exited with 0,
#
# 144e919b955c6ee98d8f6b74e9fbbed1635817a8f7ba43aac6038d6627ab3c2e
# 2021-07-15T01:47:48Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-07-15T01:47:48Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e60e1b66befcf8ee48d66ce6cb7ab93b-9c779e968d28a274-01 -sshRequired=false]
# 2021/07/15 01:47:48 Starting App Insight Logger for task:  containerSetup
# 2021/07/15 01:47:48 Version: 3.0.01650.0004 Branch: .SourceBranch Commit: 37e4354
# 2021/07/15 01:47:48 Entered ContainerSetupTask - Preparing infiniband
# 2021/07/15 01:47:48 Starting infiniband setup
# 2021/07/15 01:47:48 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/07/15 01:47:48 Returning Python Version as 3.6
# 2021-07-15T01:47:48Z VMSize: standard_d2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/07/15 01:47:48 VMSize: standard_d2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/07/15 01:47:48 VMSize: standard_d2_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/07/15 01:47:48 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021-07-15T01:47:48Z Not setting up Infiniband in Container
# 2021/07/15 01:47:48 Not setting up Infiniband in Container
# 2021/07/15 01:47:48 Not setting up Infiniband in Container
# 2021/07/15 01:47:48 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/07/15 01:47:48 Returning Python Version as 3.6
# 2021/07/15 01:47:48 sshd inside container not required for job, skipping setup.
# 2021/07/15 01:47:49 All App Insights Logs was sent successfully or the close timeout of 20 was reached
# 2021/07/15 01:47:49 App Insight Client has already been closed
# 2021/07/15 01:47:49 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-07-15T01:47:49Z Starting docker container succeeded.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2021/07/15 01:47:52 Starting App Insight Logger for task:  runTaskLet
# 2021/07/15 01:47:52 Version: 3.0.01650.0004 Branch: .SourceBranch Commit: 37e4354
# 2021/07/15 01:47:52 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/07/15 01:47:52 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-07-15T01:47:52.746211] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train.py'])
# Script type = None
# [2021-07-15T01:47:53.363107] Entering Run History Context Manager.
# [2021-07-15T01:47:54.234998] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/melbourne-ai/azureml/cifar10_cnn_experiment_1626312878_de90fada/wd/azureml/cifar10_cnn_experiment_1626312878_de90fada
# [2021-07-15T01:47:54.235268] Preparing to call script [train.py] with arguments:[]
# [2021-07-15T01:47:54.235304] After variable expansion, calling script [train.py] with arguments:[]
#
# Using TensorFlow backend.
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#
#      8192/170498071 [..............................] - ETA: 9:10
#     73728/170498071 [..............................] - ETA: 2:57
#    286720/170498071 [..............................] - ETA: 1:15
#   1105920/170498071 [..............................] - ETA: 27s
#   4300800/170498071 [..............................] - ETA: 9s
#   9281536/170498071 [>.............................] - ETA: 4s
#  14671872/170498071 [=>............................] - ETA: 3s
#  19185664/170498071 [==>...........................] - ETA: 3s
#  24797184/170498071 [===>..........................] - ETA: 2s
#  30203904/170498071 [====>.........................] - ETA: 2s
#  35454976/170498071 [=====>........................] - ETA: 2s
#  40361984/170498071 [======>.......................] - ETA: 1s
#  45309952/170498071 [======>.......................] - ETA: 1s
#  50667520/170498071 [=======>......................] - ETA: 1s
#  56172544/170498071 [========>.....................] - ETA: 1s
#  60751872/170498071 [=========>....................] - ETA: 1s
#  65953792/170498071 [==========>...................] - ETA: 1s
#  71393280/170498071 [===========>..................] - ETA: 1s
#  76816384/170498071 [============>.................] - ETA: 1s
#  82305024/170498071 [=============>................] - ETA: 1s
#  87760896/170498071 [==============>...............] - ETA: 0s
#  93323264/170498071 [===============>..............] - ETA: 0s
#  98500608/170498071 [================>.............] - ETA: 0s
# 103948288/170498071 [=================>............] - ETA: 0s
# 109387776/170498071 [==================>...........] - ETA: 0s
# 114794496/170498071 [===================>..........] - ETA: 0s
# 119250944/170498071 [===================>..........] - ETA: 0s
# 123527168/170498071 [====================>.........] - ETA: 0s
# 128180224/170498071 [=====================>........] - ETA: 0s
# 132997120/170498071 [======================>.......] - ETA: 0s
# 138313728/170498071 [=======================>......] - ETA: 0s
# 143482880/170498071 [========================>.....] - ETA: 0s
# 148348928/170498071 [=========================>....] - ETA: 0s
# 152592384/170498071 [=========================>....] - ETA: 0s
# 157745152/170498071 [==========================>...] - ETA: 0s
# 163192832/170498071 [===========================>..] - ETA: 0s
# 168730624/170498071 [============================>.] - ETA: 0s
# 170500096/170498071 [==============================] - 2s 0us/step
# 2021/07/15 01:47:57 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# WARNING:tensorflow:From /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /azureml-envs/azureml_b4a21d26b0efb58044d398c351fcba48/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2021-07-15 01:48:01.193189: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-07-15 01:48:01.197151: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2397225000 Hz
# 2021-07-15 01:48:01.197352: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55ff950f05c0 executing computations on platform Host. Devices:
# 2021-07-15 01:48:01.197383: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
#
# Streaming azureml-logs/75_job_post-tvmps_30342395f133dce1ab6228c8e04e85cebef5284b37e130f8635d4ad23e26329f_d.txt
# ===============================================================================================================
#
# [2021-07-15T01:59:04.625725] Entering job release
# [2021-07-15T01:59:05.712992] Starting job release
# [2021-07-15T01:59:05.713742] Logging experiment finalizing status in history service.
# [2021-07-15T01:59:05.714069] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 829
# [2021-07-15T01:59:05.714588] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-07-15T01:59:05.723979] Entering context manager injector.
# [2021-07-15T01:59:05.724568] job release stage : copy_batchai_cached_logs starting...
# [2021-07-15T01:59:05.724619] job release stage : copy_batchai_cached_logs completed...
# [2021-07-15T01:59:05.726428] job release stage : upload_datastore completed...
# [2021-07-15T01:59:05.726784] job release stage : execute_job_release starting...
# [2021-07-15T01:59:05.836689] job release stage : send_run_telemetry starting...
# [2021-07-15T01:59:05.855187] get vm size and vm region successfully.
# [2021-07-15T01:59:05.867147] get compute meta data successfully.
# [2021-07-15T01:59:06.037358] job release stage : execute_job_release completed...
# [2021-07-15T01:59:06.188280] post artifact meta request successfully.
# [2021-07-15T01:59:06.222700] upload compute record artifact successfully.
# [2021-07-15T01:59:06.222789] job release stage : send_run_telemetry completed...
# [2021-07-15T01:59:06.223336] Job release is complete
#
# Execution Summary
# =================
# RunId: cifar10_cnn_experiment_1626312878_de90fada
# Web View: https://ml.azure.com/runs/cifar10_cnn_experiment_1626312878_de90fada?wsid=/subscriptions/396a7442-41e6-44c6-a540-3cfdae25e2f4/resourcegroups/melbourne/workspaces/melbourne-AI&tid=543c72b0-bcc0-444e-87f2-a85936dfae52
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code",
#     "messageFormat": "{Message}",
#     "messageParameters": {
#       "Message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code"
#     },
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": {
#       "code": "UserTrainingScriptFailed",
#       "innerError": null
#     },
#     "debugInfo": null,
#     "additionalInfo": null
#   },
#   "correlation": {
#     "operation": "d1bd170e31dbcd46807c4ffa98f14d73",
#     "request": "501af6e42a8c23b0"
#   },
#   "environment": "eastus",
#   "location": "eastus",
#   "time": "2021-07-15T01:59:32.0524723+00:00",
#   "componentName": "execution-worker"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3812/2946399027.py in <module>
#       4 estimator = Estimator(compute_target=cluster, source_directory='./code', entry_script='train.py', pip_packages=['keras==2.3.0', 'tensorflow==1.13.2'])
#       5 run = exp.submit(estimator)
# ----> 6 run.wait_for_completion(show_output=True)
#
# c:\Users\yury_\projects\azure\Mastering-Azure-Machine-Learning\azure-ml\lib\site-packages\azureml\core\run.py in wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     789         if show_output:
#     790             try:
# --> 791                 self._stream_run_output(
#     792                     file_handle=sys.stdout,
#     793                     wait_post_processing=wait_post_processing,
#
# c:\Users\yury_\projects\azure\Mastering-Azure-Machine-Learning\azure-ml\lib\site-packages\azureml\core\run.py in _stream_run_output(self, file_handle, wait_post_processing, raise_on_error)
#    1034                 file_handle.write("\n")
#    1035             else:
# -> 1036                 raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#    1037
#    1038         file_handle.write("\n")
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with AttributeError: 'str' object has no attribute 'decode'",
#         "messageParameters": {},
#         "detailsUri": "https://aka.ms/azureml-run-troubleshooting",
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with AttributeError: 'str' object has no attribute 'decode'\",\n        \"messageParameters\": {},\n        \"detailsUri\": \"https://aka.ms/azureml-run-troubleshooting\",\n        \"details\": []\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %%
cluster.delete()
